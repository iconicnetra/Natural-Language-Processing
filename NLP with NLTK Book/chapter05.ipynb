# %% [markdown]
# # Chapter 05: Categorzing and Tagging Words

# %%
import nltk

# %%
text = nltk.word_tokenize("And now for something completely different")
nltk.pos_tag(text)
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %%
text = nltk.word_tokenize("They refuse to permit us to obtain the refuse permit")
nltk.pos_tag(text)
# Out:
# [('They', 'PRP'),
#  ('refuse', 'VBP'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN')]

# %%
import nltk

text = "I will book the appointment and brush my hair."
words = nltk.word_tokenize(text)
tagged = nltk.pos_tag(words)
print(tagged)
# Out:
# [('I', 'PRP'), ('will', 'MD'), ('book', 'NN'), ('the', 'DT'), ('appointment', 'NN'), ('and', 'CC'), ('brush', 'VB'), ('my', 'PRP$'), ('hair', 'NN'), ('.', '.')]

# %%
text = nltk.Text(word.lower() for word in nltk.corpus.brown.words())
text.similar('woman')
# Out:
# man time day year car moment world house family child country boy
# state job place way war girl work word

# %%
text.similar('bought')
# Out:
# made said done put had seen found given left heard was been brought
# set got that took in told felt

# %%
text.similar('beauty')
# Out:
# that and time the children place in is all more back men feet af one
# money night education death women

# %%
text.similar('over')
# Out:
# in on to of and for with from at by that into as up out down through
# is all about

# %%
text.similar('the')
# Out:
# a his this their its her an that our any all one these my in your no
# some other and

# %% [markdown]
# ## Tagged Corpora

# %% [markdown]
# ### Representing Tagged Tokens

# %%
tagged_tokens = nltk.tag.str2tuple('fly/NN')
tagged_tokens
# Out:
# ('fly', 'NN')

# %%
tagged_tokens[0]
# Out:
# 'fly'

# %%
tagged_tokens[1]
# Out:
# 'NN'

# %%
#List of taggedtokkens
sent = '''
    The/AT grand/JJ jury/NN commented/VBD on/IN a/AT number/NN of/IN
    other/AP topics/NNS ,/, AMONG/IN them/PPO the/AT Atlanta/NP and/CC
    Fulton/NP-tl County/NN-tl purchasing/VBG departments/NNS which/WDT it/PPS
    said/VBD ``/`` ARE/BER well/QL operated/VBN and/CC follow/VB generally/RB
    accepted/VBN practices/NNS which/WDT inure/VB to/IN the/AT best/JJT
    interest/NN of/IN both/ABX governments/NNS ''/'' ./.
'''
[nltk.tag.str2tuple(t) for t in sent.split()]
# Out:
# [('The', 'AT'),
#  ('grand', 'JJ'),
#  ('jury', 'NN'),
#  ('commented', 'VBD'),
#  ('on', 'IN'),
#  ('a', 'AT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('other', 'AP'),
#  ('topics', 'NNS'),
#  (',', ','),
#  ('AMONG', 'IN'),
#  ('them', 'PPO'),
#  ('the', 'AT'),
#  ('Atlanta', 'NP'),
#  ('and', 'CC'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('purchasing', 'VBG'),
#  ('departments', 'NNS'),
#  ('which', 'WDT'),
#  ('it', 'PPS'),
#  ('said', 'VBD'),
#  ('``', '``'),
#  ('ARE', 'BER'),
#  ('well', 'QL'),
#  ('operated', 'VBN'),
#  ('and', 'CC'),
#  ('follow', 'VB'),
#  ('generally', 'RB'),
#  ('accepted', 'VBN'),
#  ('practices', 'NNS'),
#  ('which', 'WDT'),
#  ('inure', 'VB'),
#  ('to', 'IN'),
#  ('the', 'AT'),
#  ('best', 'JJT'),
#  ('interest', 'NN'),
#  ('of', 'IN'),
#  ('both', 'ABX'),
#  ('governments', 'NNS'),
#  ("''", "''"),
#  ('.', '.')]

# %% [markdown]
# ### Reading taggled corpora

# %%
nltk.corpus.brown.tagged_words()
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
print(nltk.corpus.brown.tagged_words())
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
nltk.corpus.brown.conll2000.tagged_words()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 nltk.corpus.brown.conll2000.tagged_words()
#
# AttributeError: 'CategorizedTaggedCorpusReader' object has no attribute 'conll2000'

# %%
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\netra\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\treebank.zip.
# True

# %%
nltk.corpus.treebank.tagged_words()
# Out:
# [('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ...]

# %%
nltk.download('sinica_treebank')
# Out:
# [nltk_data] Downloading package sinica_treebank to
# [nltk_data]     C:\Users\netra\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\sinica_treebank.zip.
# True

# %%
nltk.corpus.sinica_treebank.tagged_words()
# Out:
# [('一', 'Neu'), ('友情', 'Nad'), ('嘉珍', 'Nba'), ...]

# %%
nltk.download('indian')
# Out:
# [nltk_data] Downloading package indian to
# [nltk_data]     C:\Users\netra\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\indian.zip.
# True

# %%
nltk.corpus.indian.tagged_words()
# Out:
# [('মহিষের', 'NN'), ('সন্তান', 'NN'), (':', 'SYM'), ...]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from nltk.corpus import brown
brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
tag_fd.keys()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[46], line 3
#       1 from nltk.corpus import brown
#       2 brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
# ----> 3 tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
#       4 tag_fd.keys()
#
# File e:\Python\myenv\Lib\site-packages\nltk\probability.py:102, in FreqDist.__init__(self, samples)
#      86 def __init__(self, samples=None):
#      87     """
#      88     Construct a new frequency distribution.  If ``samples`` is
#      89     given, then the frequency distribution will be initialized
#    (...)
#     100     :type samples: Sequence
#     101     """
# --> 102     Counter.__init__(self, samples)
#     104     # Cached number of samples in this FreqDist
#     105     self._N = None
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\collections\__init__.py:599, in Counter.__init__(self, iterable, **kwds)
#     588 '''Create a new, empty Counter object.  And if given, count elements
#     589 from an input iterable.  Or, initialize the count from another mapping
#     590 of elements to their counts.
#    (...)
#     596
#     597 '''
#     598 super().__init__()
# --> 599 self.update(iterable, **kwds)
#
# File e:\Python\myenv\Lib\site-packages\nltk\probability.py:140, in FreqDist.update(self, *args, **kwargs)
#     136 """
#     137 Override ``Counter.update()`` to invalidate the cached N
#     138 """
#     139 self._N = None
# --> 140 super().update(*args, **kwargs)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\collections\__init__.py:690, in Counter.update(self, iterable, **kwds)
#     688             super().update(iterable)
#     689     else:
# --> 690         _count_elements(self, iterable)
#     691 if kwds:
#     692     self.update(kwds)
#
# Cell In[46], line 3, in <genexpr>(.0)
#       1 from nltk.corpus import brown
#       2 brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
# ----> 3 tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
#       4 tag_fd.keys()
#
# File e:\Python\myenv\Lib\site-packages\nltk\corpus\reader\util.py:424, in ConcatenatedCorpusView.iterate_from(self, start_tok)
#     421     self._open_piece = piece
#     423 # Get everything we can from this piece.
# --> 424 yield from piece.iterate_from(max(0, start_tok - offset))
#     426 # Update the offset table.
#     427 if piecenum + 1 == len(self._offsets):
#
# File e:\Python\myenv\Lib\site-packages\nltk\corpus\reader\util.py:306, in StreamBackedCorpusView.iterate_from(self, start_tok)
#     304 self._current_toknum = toknum
#     305 self._current_blocknum = block_index
# --> 306 tokens = self.read_block(self._stream)
#     307 assert isinstance(tokens, (tuple, list, AbstractLazySequence)), (
#     308     "block reader %s() should return list or tuple."
#     309     % self.read_block.__name__
#     310 )
#     311 num_toks = len(tokens)
#
# File e:\Python\myenv\Lib\site-packages\nltk\corpus\reader\tagged.py:298, in TaggedCorpusView.read_block(self, stream)
#     293 sent = [
#     294     str2tuple(s, self._sep)
#     295     for s in self._word_tokenizer.tokenize(sent_str)
#     296 ]
#     297 if self._tag_mapping_function:
# --> 298     sent = [(w, self._tag_mapping_function(t)) for (w, t) in sent]
#     299 if not self._tagged:
#     300     sent = [w for (w, t) in sent]
#
# File e:\Python\myenv\Lib\site-packages\nltk\corpus\reader\tagged.py:298, in <listcomp>(.0)
#     293 sent = [
#     294     str2tuple(s, self._sep)
#     295     for s in self._word_tokenizer.tokenize(sent_str)
#     296 ]
#     297 if self._tag_mapping_function:
# --> 298     sent = [(w, self._tag_mapping_function(t)) for (w, t) in sent]
#     299 if not self._tagged:
#     300     sent = [w for (w, t) in sent]
#
# File e:\Python\myenv\Lib\site-packages\nltk\corpus\reader\tagged.py:149, in TaggedCorpusReader.tagged_words.<locals>.<lambda>(t)
#     142 """
#     143 :return: the given file(s) as a list of tagged
#     144     words and punctuation symbols, encoded as tuples
#     145     ``(word,tag)``.
#     146 :rtype: list(tuple(str,str))
#     147 """
#     148 if tagset and tagset != self._tagset:
# --> 149     tag_mapping_function = lambda t: map_tag(self._tagset, tagset, t)
#     150 else:
#     151     tag_mapping_function = None
#
# File e:\Python\myenv\Lib\site-packages\nltk\tag\mapping.py:136, in map_tag(source, target, source_tag)
#     133     if source == "brown":
#     134         source = "en-brown"
# --> 136 return tagset_mapping(source, target)[source_tag]
#
# File e:\Python\myenv\Lib\site-packages\nltk\tag\mapping.py:91, in tagset_mapping(source, target)
#      89 if source not in _MAPPINGS or target not in _MAPPINGS[source]:
#      90     if target == "universal":
# ---> 91         _load_universal_map(source)
#      92         # Added the new Russian National Corpus mappings because the
#      93         # Russian model for nltk.pos_tag() uses it.
#      94         _MAPPINGS["ru-rnc-new"]["universal"] = {
#      95             "A": "ADJ",
#      96             "A-PRO": "PRON",
#    (...)
#     111             "V": "VERB",
#     112         }
#
# File e:\Python\myenv\Lib\site-packages\nltk\tag\mapping.py:59, in _load_universal_map(fileid)
#      58 def _load_universal_map(fileid):
# ---> 59     contents = load(join(_UNIVERSAL_DATA, fileid + ".map"), format="text")
#      61     # When mapping to the Universal Tagset,
#      62     # map unknown inputs to 'X' not 'UNK'
#      63     _MAPPINGS[fileid]["universal"].default_factory = lambda: "X"
#
# File e:\Python\myenv\Lib\site-packages\nltk\data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File e:\Python\myenv\Lib\site-packages\nltk\data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File e:\Python\myenv\Lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource universal_tagset not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('universal_tagset')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/universal_tagset/en-brown.map
#
#   Searched in:
#     - 'C:\\Users\\netra/nltk_data'
#     - 'e:\\Python\\myenv\\nltk_data'
#     - 'e:\\Python\\myenv\\share\\nltk_data'
#     - 'e:\\Python\\myenv\\lib\\nltk_data'
#     - 'C:\\Users\\netra\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - ''
# **********************************************************************

# %%
wsj = nltk.corpus.treebank.tagged_words(simplify_tags = True)

word_tag_fd = nltk.FreqDist(wsj)
[wt for (wt, _) in word_tag_fd.most_common() if wt[1] == 'VERB']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 wsj = nltk.corpus.treebank.tagged_words(simplify_tags = True)
#       3 word_tag_fd = nltk.FreqDist(wsj)
#       4 [wt for (wt, _) in word_tag_fd.most_common() if wt[1] == 'VERB']
#
# TypeError: SyntaxCorpusReader.tagged_words() got an unexpected keyword argument 'simplify_tags'

# %%
from nltk.corpus import brown
brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
tag_fd.keys()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[20], line 3
#       1 from nltk.corpus import brown
#       2 brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
# ----> 3 tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
#       4 tag_fd.keys()
#
# File e:\Python\myenv\Lib\site-packages\nltk\probability.py:102, in FreqDist.__init__(self, samples)
#      86 def __init__(self, samples=None):
#      87     """
#      88     Construct a new frequency distribution.  If ``samples`` is
#      89     given, then the frequency distribution will be initialized
#    (...)
#     100     :type samples: Sequence
#     101     """
# --> 102     Counter.__init__(self, samples)
#     104     # Cached number of samples in this FreqDist
#     105     self._N = None
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\collections\__init__.py:599, in Counter.__init__(self, iterable, **kwds)
#     588 '''Create a new, empty Counter object.  And if given, count elements
#     589 from an input iterable.  Or, initialize the count from another mapping
#     590 of elements to their counts.
#    (...)
#     596
#     597 '''
#     598 super().__init__()
# --> 599 self.update(iterable, **kwds)
#
# File e:\Python\myenv\Lib\site-packages\nltk\probability.py:140, in FreqDist.update(self, *args, **kwargs)
#     136 """
#     137 Override ``Counter.update()`` to invalidate the cached N
#     138 """
#     139 self._N = None
# --> 140 super().update(*args, **kwargs)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\collections\__init__.py:690, in Counter.update(self, iterable, **kwds)
#     688             super().update(iterable)
#     689     else:
# --> 690         _count_elements(self, iterable)
#     691 if kwds:
#     692     self.update(kwds)
#
# Cell In[20], line 3, in <genexpr>(.0)
#       1 from nltk.corpus import brown
#       2 brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
# ----> 3 tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
#       4 tag_fd.keys()
#
# File e:\Python\myenv\Lib\site-packages\nltk\corpus\reader\util.py:424, in ConcatenatedCorpusView.iterate_from(self, start_tok)
#     421     self._open_piece = piece
#     423 # Get everything we can from this piece.
# --> 424 yield from piece.iterate_from(max(0, start_tok - offset))
#     426 # Update the offset table.
#     427 if piecenum + 1 == len(self._offsets):
#
# File e:\Python\myenv\Lib\site-packages\nltk\corpus\reader\util.py:306, in StreamBackedCorpusView.iterate_from(self, start_tok)
#     304 self._current_toknum = toknum
#     305 self._current_blocknum = block_index
# --> 306 tokens = self.read_block(self._stream)
#     307 assert isinstance(tokens, (tuple, list, AbstractLazySequence)), (
#     308     "block reader %s() should return list or tuple."
#     309     % self.read_block.__name__
#     310 )
#     311 num_toks = len(tokens)
#
# File e:\Python\myenv\Lib\site-packages\nltk\corpus\reader\tagged.py:298, in TaggedCorpusView.read_block(self, stream)
#     293 sent = [
#     294     str2tuple(s, self._sep)
#     295     for s in self._word_tokenizer.tokenize(sent_str)
#     296 ]
#     297 if self._tag_mapping_function:
# --> 298     sent = [(w, self._tag_mapping_function(t)) for (w, t) in sent]
#     299 if not self._tagged:
#     300     sent = [w for (w, t) in sent]
#
# File e:\Python\myenv\Lib\site-packages\nltk\corpus\reader\tagged.py:298, in <listcomp>(.0)
#     293 sent = [
#     294     str2tuple(s, self._sep)
#     295     for s in self._word_tokenizer.tokenize(sent_str)
#     296 ]
#     297 if self._tag_mapping_function:
# --> 298     sent = [(w, self._tag_mapping_function(t)) for (w, t) in sent]
#     299 if not self._tagged:
#     300     sent = [w for (w, t) in sent]
#
# File e:\Python\myenv\Lib\site-packages\nltk\corpus\reader\tagged.py:149, in TaggedCorpusReader.tagged_words.<locals>.<lambda>(t)
#     142 """
#     143 :return: the given file(s) as a list of tagged
#     144     words and punctuation symbols, encoded as tuples
#     145     ``(word,tag)``.
#     146 :rtype: list(tuple(str,str))
#     147 """
#     148 if tagset and tagset != self._tagset:
# --> 149     tag_mapping_function = lambda t: map_tag(self._tagset, tagset, t)
#     150 else:
#     151     tag_mapping_function = None
#
# File e:\Python\myenv\Lib\site-packages\nltk\tag\mapping.py:136, in map_tag(source, target, source_tag)
#     133     if source == "brown":
#     134         source = "en-brown"
# --> 136 return tagset_mapping(source, target)[source_tag]
#
# File e:\Python\myenv\Lib\site-packages\nltk\tag\mapping.py:91, in tagset_mapping(source, target)
#      89 if source not in _MAPPINGS or target not in _MAPPINGS[source]:
#      90     if target == "universal":
# ---> 91         _load_universal_map(source)
#      92         # Added the new Russian National Corpus mappings because the
#      93         # Russian model for nltk.pos_tag() uses it.
#      94         _MAPPINGS["ru-rnc-new"]["universal"] = {
#      95             "A": "ADJ",
#      96             "A-PRO": "PRON",
#    (...)
#     111             "V": "VERB",
#     112         }
#
# File e:\Python\myenv\Lib\site-packages\nltk\tag\mapping.py:59, in _load_universal_map(fileid)
#      58 def _load_universal_map(fileid):
# ---> 59     contents = load(join(_UNIVERSAL_DATA, fileid + ".map"), format="text")
#      61     # When mapping to the Universal Tagset,
#      62     # map unknown inputs to 'X' not 'UNK'
#      63     _MAPPINGS[fileid]["universal"].default_factory = lambda: "X"
#
# File e:\Python\myenv\Lib\site-packages\nltk\data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File e:\Python\myenv\Lib\site-packages\nltk\data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File e:\Python\myenv\Lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource universal_tagset not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('universal_tagset')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/universal_tagset/en-brown.map
#
#   Searched in:
#     - 'C:\\Users\\netra/nltk_data'
#     - 'e:\\Python\\myenv\\nltk_data'
#     - 'e:\\Python\\myenv\\share\\nltk_data'
#     - 'e:\\Python\\myenv\\lib\\nltk_data'
#     - 'C:\\Users\\netra\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - ''
# **********************************************************************

# %%
tag_fd.plot(cumulative=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 tag_fd.plot(cumulative=True)
#
# NameError: name 'tag_fd' is not defined
